# %%
import pandas as pd
from pycaret.regression import *

# %%
df = pd.read_csv("^IXIC.csv")
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2019-10-14   8044.350098   8069.850098   8036.410156   8048.649902
# 1    2019-10-15   8074.850098   8166.180176   8071.810059   8148.709961
# 2    2019-10-16   8119.810059   8146.149902   8103.379883   8124.180176
# 3    2019-10-17   8176.910156   8183.640137   8131.250000   8156.850098
# 4    2019-10-18   8149.850098   8157.359863   8045.370117   8089.540039
# ..          ...           ...           ...           ...           ...
# 246  2020-10-05  11169.110352  11335.209961  11162.519531  11332.490234
# 247  2020-10-06  11314.530273  11392.410156  11124.450195  11154.599609
# 248  2020-10-07  11271.679688  11380.559570  11258.349609  11364.599609
# 249  2020-10-08  11443.349609  11448.230469  11384.330078  11420.980469
# 250  2020-10-09  11487.599609  11581.230469  11476.660156  11579.940430
#
#         Adj Close      Volume
# 0     8048.649902  1419730000
# 1     8148.709961  1836650000
# ...

# %%
setter = setup(df, target = 'Close', ignore_features=['Open', 'High', 'Low', 'Adj Close', 'Volume'])
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# </style><table id="T_d5b74762_0c3d_11eb_a274_5076af0a4659" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d5b74762_0c3d_11eb_a274_5076af0a4659level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d5b74762_0c3d_11eb_a274_5076af0a4659row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d5b74762_0c3d_11eb_a274_5076af0a4659row0_col1" class="data row0 col1" >3558</td>
#             </tr>
#             <tr>
#                         <th id="T_d5b74762_0c3d_11eb_a274_5076af0a4659level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d5b74762_0c3d_11eb_a274_5076af0a4659row1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %%
bester = compare_models(sort='MSE', n_select=3)
# Out:
# <style  type="text/css" >
#     #T_eeb7fbcc_0c3d_11eb_9ba6_5076af0a4659 th {
#           text-align: left;
# ...

# %%
bModel = blend_models(estimator_list = bester,  fold = 10, optimize = 'MSE', turbo = True, verbose = True)
# Out:
# <style  type="text/css" >
# #T_1a629b88_0c3e_11eb_9189_5076af0a4659row10_col0,#T_1a629b88_0c3e_11eb_9189_5076af0a4659row10_col1,#T_1a629b88_0c3e_11eb_9189_5076af0a4659row10_col2,#T_1a629b88_0c3e_11eb_9189_5076af0a4659row10_col3,#T_1a629b88_0c3e_11eb_9189_5076af0a4659row10_col4,#T_1a629b88_0c3e_11eb_9189_5076af0a4659row10_col5{
#             background:  yellow;
#         }</style><table id="T_1a629b88_0c3e_11eb_9189_5076af0a4659" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a629b88_0c3e_11eb_9189_5076af0a4659level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(bModel)

# %%
plot_model(bModel, plot='learning')

# %%
plot_model(bModel, plot='manifold')

# %%
plot_model(bModel, plot='error')
